# %% [markdown]
# ### **Data Section**

# %% [markdown]
# In order to answer the above business problem, data on New York City boroughs, neighborhoods and location coordinates are required. Additionally, restaurants and restaurant ratings are essential.
#
# New York City data containing boroughs, neighborhoods and location coordinates will be obtained from the data source: https://cocl.us/new_york_dataset.
# Data related to the locations and ratings of vegan restaurants will be obtained by utilizing Foursquare’s Application Programming Interface (API).
